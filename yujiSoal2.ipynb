# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import mode, zscore

# %%
df1 = pd.read_csv('2015.csv')
df2 = pd.read_csv('2016.csv')
df3 = pd.read_csv('2017.csv')
df4 = pd.read_csv('2018.csv')
df5 = pd.read_csv('2019.csv')

# gbg = pd.merge(df1,df4,on='Country')
# print(df1.columns)
# print(df2.columns)
# print(df3.columns)
# print(df4.columns)
# print(df5.columns)
print(df1.info())
print(df2.info())
print(df3.info())
print(df4.info())
print(df5.info())

# %%
kolom1 = ['Country', 'Region', 'Happiness Rank', 'Happiness Score',
       'Standard Error', 'GDP', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Government Corruption',
       'Generosity', 'Dystopia Residual']
kolom2 = ['Country', 'Region', 'Happiness Rank', 'Happiness Score',
       'Lower Confidence Interval', 'Upper Confidence Interval',
       'GDP', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Government Corruption', 'Generosity','Dystopia Residual']
kolom3 = ['Country', 'Happiness Rank', 'Happiness Score', 'Upper Confidence Interval',
       'Lower Confidence Interval', 'GDP', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Government Corruption.', 'Dystopia Residual']
kolom4 = ['Happiness Rank','Country', 'Happiness Score', 'GDP', 'Social support',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Government Corruption']
kolom5 = ['Happiness Rank','Country', 'Happiness Score', 'GDP', 'Social support',
       'Health (Life Expectancy)', 'Freedom', 'Generosity',
       'Government Corruption']

df1.columns = kolom1
df1.index = pd.date_range('20150101', periods=158)
df2.columns = kolom2
df2.index = pd.date_range('20160101', periods=157)
df3.columns = kolom3
df3.index = pd.date_range('20170101', periods=155)
df4.columns = kolom4
df4.index = pd.date_range('20180101', periods=156)
df5.columns = kolom5
df5.index = pd.date_range('20190101', periods=156)

gbg = [df1,df2,df3,df4,df5]
data = pd.concat(gbg)

# fillna
data = data.fillna({
    'Region': 'None',
})
data = data.ffill(axis=1)
# data = data.bfill(axis=1)
# data = data.interpolate(method='linear')

# data['Region'] = data['Region'].replace([np.NaN,'None'])
# data.tail()

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     print(data)

# %%
df1.describe()

# %%
df4 = df4[['Country or region','Score','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]
df5 = df5[['Country or region','Score','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']]

df1num = df1[['Happiness Score',
       'Standard Error', 'Economy (GDP per Capita)', 'Family',
       'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
       'Generosity', 'Dystopia Residual']]
# mean median std deviation
mean1 = df1.describe()
# mode
mode1 = mode(df1)
# Range 2015 
df1range = df1num.max() - df1num.min()
# IQR 2015
df1iqr = df1num.quantile(.75) - df1num.quantile(.25)
# Z Score
z1 = zscore(df1num)
# outlier
high1 = df1num.quantile(.75) + (1.5*df1iqr)
low1 = df1num.quantile(.25) - (1.5*df1iqr)
# Zscore method
# highz1 = df1num.mean() - (z1*df1.std())
# lowz1 = df1num.mean() + (z1*df1.std())


df2num = df2[['Happiness Score',
       'Lower Confidence Interval', 'Upper Confidence Interval',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Trust (Government Corruption)', 'Generosity',
       'Dystopia Residual']]

# mean median std deviation
mean2 = df2.describe()
# mode
mode2 = mode(df2)
# Range 2016 
df2range = df2num.max() - df2num.min()
# IQR 2016
df2iqr = df2num.quantile(.75) - df2num.quantile(.25)
# Z Score
z2 = zscore(df2num)
# outlier
high2 = df2num.quantile(.75) + (1.5*df2iqr)
low2 = df2num.quantile(.25) - (1.5*df2iqr)
# Zscore method
# highz2 = df2num.mean() - (z2*df2.std())
# lowz2 = df2num.mean() + (z2*df2.std())


df3num = df3[['Happiness.Score', 'Whisker.high',
       'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.', 'Dystopia.Residual']]

# mean median std deviation
mean3 = df3.describe()
# mode
mode3 = mode(df3)
# Range 2017 
df3range = df3num.max() - df3num.min()
# IQR 2017
df3iqr = df3num.quantile(.75) - df3num.quantile(.25)
# Z Score
z3 = zscore(df3num)
# outlier
high3 = df3num.quantile(.75) + (1.5*df3iqr)
low3 = df3num.quantile(.25) - (1.5*df3iqr)
# Zscore method
# highz3 = df3num.mean() - (z3*df3.std())
# lowz3 = df3num.mean() + (z3*df3.std())


df4num = df4[['Score', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# mean median std deviation
mean4 = df4.describe()
# mode
mode4 = mode(df4)
# Range 2018 
df4range = df4num.max() - df4num.min()
# IQR 2018
df4iqr = df4num.quantile(.75) - df4num.quantile(.25)
# Z Score
z4 = zscore(df4num)
z4 = pd.DataFrame(z4)
# outlier
high4 = df4num.quantile(.75) + (1.5*df4iqr)
low4 = df4num.quantile(.25) - (1.5*df4iqr)
# Zscore method
# highz4 = df4num.mean() - (z4*df4.std())
# lowz4 = df4num.mean() + (z3*df4.std())

df5num = df5[['Score', 'GDP per capita', 'Social support',
       'Healthy life expectancy', 'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# mean median std deviation
mean5 = df5.describe()
# mode
mode5 = mode(df5)
# Range 2019 
df5range = df5num.max() - df5num.min()
# IQR 2018
df5iqr = df5num.quantile(.75) - df5num.quantile(.25)
# Z Score
z5 = zscore(df5num)
# outlier
high5 = df5num.quantile(.75) + (1.5*df5iqr)
low5 = df5num.quantile(.25) - (1.5*df5iqr)
# Zscore method
# highz5 = df5num.mean() - (z5*df5.std())
# lowz5 = df5num.mean() + (z5*df5.std())

# %%
df1num.plot(kind='box',figsize=(10,5))
plt.grid(True)
plt.xticks(rotation=90)

# %%
df2num.plot(kind='box',figsize=(10,5))
plt.grid(True)
plt.xticks(rotation=90)

# %%
df3num.plot(kind='box',figsize=(10,5))
plt.grid(True)
plt.xticks(rotation=90)

# %%
df4num.plot(kind='box',figsize=(10,5))
plt.grid(True)
plt.xticks(rotation=90)

# %%
df5num.plot(kind='box',figsize=(10,5))
plt.grid(True)
plt.xticks(rotation=90)
